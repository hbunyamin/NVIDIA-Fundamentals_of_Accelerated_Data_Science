# %% [markdown]
# <a href="https://www.nvidia.com/dli"><img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

str_path = "/content/drive/MyDrive/NVIDIA/Fundamentals_of_Accelerated_Data_Science/Assessment"
base_path = Path(str_path)

# %%
# This get the RAPIDS-Colab install files and test check your GPU.  Run this and the next cell only.
# Please read the output of this cell.  If your Colab Instance is not RAPIDS compatible, it will warn you and give you remediation steps.
# !git clone https://github.com/rapidsai/rapidsai-csp-utils.git
# !python rapidsai-csp-utils/colab/pip-install.py
# Out:
# Cloning into 'rapidsai-csp-utils'...
# remote: Enumerating objects: 621, done.
# remote: Counting objects: 100% (187/187), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 621 (delta 143), reused 86 (delta 85), pack-reused 434 (from 3)
# Receiving objects: 100% (621/621), 205.72 KiB | 2.00 MiB/s, done.
# Resolving deltas: 100% (317/317), done.
# Installing RAPIDS remaining 25.10 libraries
# Using Python 3.12.12 environment at: /usr
# Resolved 175 packages in 12.74s
# Prepared 18 packages in 1m 19s
# Uninstalled 11 packages in 168ms
# Installed 18 packages in 37ms
#  - bokeh==3.7.3
#  + bokeh==3.6.3
#  + cucim-cu12==25.10.0
#  + cugraph-cu12==25.10.1
#  + cuxfilter-cu12==25.10.0
#  + datashader==0.18.2
#  - holoviews==1.22.1
#  + holoviews==1.20.2
#  + jupyter-server-proxy==4.4.0
#  - nvidia-cublas-cu12==12.6.4.1
#  + nvidia-cublas-cu12==12.9.1.4
#  - nvidia-cuda-nvcc-cu12==12.5.82
#  + nvidia-cuda-nvcc-cu12==12.9.86
#  - nvidia-cuda-nvrtc-cu12==12.6.77
#  + nvidia-cuda-nvrtc-cu12==12.9.86
#  - nvidia-cufft-cu12==11.3.0.4
#  + nvidia-cufft-cu12==11.4.1.4
#  - nvidia-curand-cu12==10.3.7.77
#  + nvidia-curand-cu12==10.3.10.19
#  - nvidia-cusolver-cu12==11.7.1.2
#  + nvidia-cusolver-cu12==11.7.5.82
#  - nvidia-cusparse-cu12==12.5.4.2
#  + nvidia-cusparse-cu12==12.5.10.65
#  - panel==1.8.4
#  + panel==1.7.5
#  + pyct==0.6.0
#  - shapely==2.1.2
#  + shapely==2.0.7
#  + simpervisor==1.0.0
#
#         ***********************************************************************
#         The pip install of RAPIDS is complete.
#
#         Please do not run any further installation from the conda based installation methods, as they may cause issues!
#
#         Please ensure that you're pulling from the git repo to remain updated with the latest working install scripts.
#
#         Troubleshooting:
#             - If there is an installation failure, please check back on RAPIDSAI owned templates/notebooks to see how to update your personal files.
#             - If an installation failure persists when using the latest script, please make an issue on https://github.com/rapidsai-community/rapidsai-csp-utils
#         ***********************************************************************

# %% [markdown]
# # Week 2: Identify Nearest Health Facilities

# %% [markdown]
# <span style="color:red">
# **UPDATE**
#
# Thank you for your analysis. Despite our warning efforts so far, the virus continues to spread rapidly. We want to get infected individuals treatment as quickly as possible, so we need your help to calculate which hospital or clinic is closest to each known infected individual in the population.
# </span>
#
# Your goal for this notebook will be to identify the nearest hospital or clinic for each infected person.

# %% [markdown]
# ## Imports

# %%
# %load_ext cudf.pandas
import pandas as pd
import cuml
import cupy as cp

# %% [markdown]
# ## Load Population Data

# %% [markdown]
# Begin by loading the `lat`, `long` and `infected` columns from `'./data/week2.csv'` into a cuDF-accelerated pandas DataFrame called `df`.

# %%
#df = pd.read_csv("./data/week2.csv")
df = pd.read_csv(Path(base_path, "data", "week2.csv"))
df
# Out:
#                 lat      long  infected
# 0         54.522510 -1.571896       0.0
# 1         54.554030 -1.524968       0.0
# 2         54.552486 -1.435203       0.0
# 3         54.537189 -1.566215       0.0
# 4         54.528212 -1.588462       0.0
# ...             ...       ...       ...
# 58479889  51.634416 -2.925863       0.0
# 58479890  51.556972 -3.036290       0.0
# 58479891  51.588992 -2.921915       0.0
# 58479892  51.590974 -2.954539       0.0
# 58479893  51.576716 -2.952142       0.0
#
# [58479894 rows x 3 columns]

# %% [markdown]
# ## Load Hospital and Clinics Data

# %% [markdown]
# For this step, your goal is to create an `all_med` cuDF-accelearted pandas DataFrame that contains the latitudes and longitudes of all the hospitals (data found at `'./data/hospitals.csv'`) and clinics (data found at `'./data/clinics.csv'`).

# %%
#hospitals_df = pd.read_csv(<<<<FIXME>>>>)
hospitals_df = pd.read_csv(Path(base_path, "data", "hospitals.csv"))
hospitals_df
# Out:
#       OrganisationID OrganisationCode OrganisationType   SubType  \
# 0              17970            NDA07         Hospital  Hospital
# 1              17981            NDA18         Hospital  Hospital
# 2              18102            NLT02         Hospital  Hospital
# 3              18138            NMP01         Hospital  Hospital
# 4              18142            NMV01         Hospital  Hospital
# ...              ...              ...              ...       ...
# 1224        10617466            RTH18         Hospital   UNKNOWN
# 1225        10617482            RX3KI         Hospital   UNKNOWN
# 1226        10617567            RGT1W         Hospital   UNKNOWN
# 1227        10617714            RAX0A         Hospital   UNKNOWN
# 1228        10617726            RDU5A         Hospital   UNKNOWN
#
#                   Sector OrganisationStatus  IsPimsManaged  \
# 0     Independent Sector            Visible           True
# 1     Independent Sector            Visible           True
# 2             NHS Sector            Visible           True
# 3     Independent Sector            Visible          False
# 4     Independent Sector            Visible           True
# ...                  ...                ...            ...
# 1224  Independent Sector            Visible          False
# 1225  Independent Sector            Visible          False
# 1226  Independent Sector            Visible          False
# 1227  Independent Sector            Visible          False
# 1228  Independent Sector            Visible          False
#
#                                        OrganisationName  \
# 0     Walton Community Hospital - Virgin Care Servic...
# 1               Woking Community Hospital (Virgin Care)
# 2                     North Somerset Community Hospital
# 3                                  Bridgewater Hospital
# 4                                      Kneesworth House
# ...                                                 ...
# 1224                       University Hospital Of Wales
# 1225                                 Foss Park Hospital
# 1226                            Jersey General Hospital
# 1227             London North West University Hospitals
# 1228                            John Radcliffe Hospital
#
#                                Address1        Address2  ...  \
# 0                                  None     Rodney Road  ...
# 1                                  None  Heathside Road  ...
# 2     North Somerset Community Hospital      Old Street  ...
# 3                     120 Princess Road            None  ...
# 4                        Old North Road    Bassingbourn  ...
# ...                                 ...             ...  ...
# 1224        C/O John Radcliffe Hospital     Headley Way  ...
# 1225                   Huntington House     Jockey Lane  ...
# 1226                         The Parade            None  ...
# 1227                       Watford Road            None  ...
# 1228                        Headley Way      Headington  ...
#
#                   County  Postcode     Latitude     Longitude ParentODSCode  \
# 0                 Surrey  KT12 3LD  51.37999725  -0.406042069           NDA
# 1                 Surrey  GU22 7HS  51.31513214  -0.556289494           NDA
# 2                   Avon  BS21 6BS  51.43719482  -2.847192764           NLT
# 3     Greater Manchester   M15 5AT   53.4597435  -2.245468855           NMP
# 4                   None   SG8 5JP  52.07812119  -0.030604055           NMV
# ...                  ...       ...          ...           ...           ...
# 1224                None   OX3 9DU  51.76387405  -1.219792008           RTH
# 1225                None  YO32 9XW  53.98666382  -1.051122308           RX3
# 1226                None   JE1 3UH          nan           nan           RGT
# 1227                None   HA1 3UJ  51.57540894  -0.322022736           RAX
# 1228                None   OX3 9DU  51.76387405  -1.219792008           RDU
#
#                                              ParentName          Phone  \
# 0                              Virgin Care Services Ltd   01932 414205
# 1                              Virgin Care Services Ltd   01483 715911
# 2     North Somerset Community Partnership Community...   01275 872212
# 3                 Bridgewater Hospital (Manchester) Ltd   0161 2270000
# 4                              Partnerships In Care Ltd  01763 255 700
# ...                                                 ...            ...
# 1224   Oxford University Hospitals NHS Foundation Trust           None
# 1225    Tees, Esk and Wear Valleys NHS Foundation Trust           None
# 1226  Cambridge University Hospitals NHS Foundation ...           None
# 1227             Kingston Hospital NHS Foundation Trust           None
# 1228                Frimley Health NHS Foundation Trust           None
#
#                                                   Email  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4     reception_kneesworthhouse@partnershipsincare.c...
# ...                                                 ...
# 1224                                               None
# 1225                                               None
# 1226                                               None
# 1227                                               None
# 1228                                               None
#
#                            Website           Fax
# 0                             None  01932 253674
# 1                             None          None
# 2      http://www.nscphealth.co.uk          None
# 3      www.bridgewaterhospital.com          None
# 4     www.partnershipsincare.co.uk          None
# ...                            ...           ...
# 1224                          None          None
# 1225                          None          None
# 1226                          None          None
# 1227                          None          None
# 1228                          None          None
#
# [1229 rows x 22 columns]

# %%
#clinics_df = pd.read_csv(<<<<FIXME>>>>)
clinics_df = pd.read_csv(Path(base_path, "data", "clinics.csv"))
clinics_df
# Out:
#        OrganisationID OrganisationCode OrganisationType  SubType  \
# 0               12366           F81157           Clinic  UNKNOWN
# 1               12450           F81670           Clinic  UNKNOWN
# 2               12461           F81681           Clinic  UNKNOWN
# 3               17937            NAA01           Clinic  UNKNOWN
# 4               17938            NAA02           Clinic  UNKNOWN
# ...               ...              ...              ...      ...
# 19077        10617742            NBG7L           Clinic  UNKNOWN
# 19078        10617743            NFH02           Clinic  UNKNOWN
# 19079        10617744            NFH03           Clinic  UNKNOWN
# 19080        10617746            NEMAM           Clinic  UNKNOWN
# 19081        10617747            NFH04           Clinic  UNKNOWN
#
#       OrganisationStatus  IsPimsManaged  \
# 0                Visible           True
# 1                Visible           True
# 2                Visible           True
# 3                Visible          False
# 4                Visible          False
# ...                  ...            ...
# 19077            Visible          False
# 19078            Visible          False
# 19079            Visible          False
# 19080            Visible          False
# 19081            Visible          False
#
#                                         OrganisationName           Address1  \
# 0                            Frinton Road Medical Centre               None
# 1                                   Epping Close Surgery               None
# 2                              Green Elms Medical Centre               None
# 3                                        St Chads Clinic    St. Chads Drive
# 4                                  Whiston Health Centre  Old Colliery Road
# ...                                                  ...                ...
# 19077                           Sunnybank Medical Centre          Town Gate
# 19078  Somerset Surgical Services At Mendip Vale Medi...   Pudding Pie Lane
# 19079  Somerset Surgical Services At Axbridge Medical...       Houlgate Way
# 19080                               Lawton House Surgery       Bromley Road
# 19081  Somerset Surgical Services At Wedmore Medical ...    St. Medard Road
#
#                               Address2 Address3                     City  \
# 0      68 Frinton Road, Hollond-on-Sea     None           Clacton-on-Sea
# 1                         Epping Close     None           Clacton on Sea
# 2                         32 Crossways     None  Jaywick, Clacton on Sea
# 3                                 None     None                Liverpool
# 4                              Whiston     None                  Prescot
# ...                                ...      ...                      ...
# 19077                             Wyke     None                 Bradford
# 19078                         Langford     None                  Bristol
# 19079                             None     None                 Axbridge
# 19080                             None     None                Congleton
# 19081                             None     None                  Wedmore
#
#            County  Postcode   Latitude  Longitude         Phone Email Website  \
# 0            None  CO15 5UW  51.804237   1.186376          None  None    None
# 1            None  CO15 4UZ  51.815262   1.154707  01255 222668  None    None
# 2            None  CO15 2NB  51.780621   1.117907          None  None    None
# 3      Merseyside   L32 8RE  53.482368  -2.885404          None  None    None
# 4      Merseyside   L35 3SX  53.415630  -2.800874          None  None    None
# ...           ...       ...        ...        ...           ...   ...     ...
# 19077        None  BD12 9NG  53.737923  -1.767982          None  None    None
# 19078        None  BS40 5EL  51.341579  -2.784808          None  None    None
# 19079        None  BS26 2BJ  51.286285  -2.820388          None  None    None
# 19080        None  CW12 1QG  53.163048  -2.205781          None  None    None
# 19081        None  BS28 4AY  51.227219  -2.816258          None  None    None
#
#         Fax
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ...     ...
# 19077  None
# 19078  None
# 19079  None
# 19080  None
# 19081  None
#
# [19082 rows x 19 columns]

# %%
all_med = pd.concat([hospitals_df, clinics_df])
all_med
# Out:
#        OrganisationID OrganisationCode OrganisationType   SubType  \
# 0               17970            NDA07         Hospital  Hospital
# 1               17981            NDA18         Hospital  Hospital
# 2               18102            NLT02         Hospital  Hospital
# 3               18138            NMP01         Hospital  Hospital
# 4               18142            NMV01         Hospital  Hospital
# ...               ...              ...              ...       ...
# 19077        10617742            NBG7L           Clinic   UNKNOWN
# 19078        10617743            NFH02           Clinic   UNKNOWN
# 19079        10617744            NFH03           Clinic   UNKNOWN
# 19080        10617746            NEMAM           Clinic   UNKNOWN
# 19081        10617747            NFH04           Clinic   UNKNOWN
#
#                    Sector OrganisationStatus  IsPimsManaged  \
# 0      Independent Sector            Visible           True
# 1      Independent Sector            Visible           True
# 2              NHS Sector            Visible           True
# 3      Independent Sector            Visible          False
# 4      Independent Sector            Visible           True
# ...                   ...                ...            ...
# 19077                None            Visible          False
# 19078                None            Visible          False
# 19079                None            Visible          False
# 19080                None            Visible          False
# 19081                None            Visible          False
#
#                                         OrganisationName  \
# 0      Walton Community Hospital - Virgin Care Servic...
# 1                Woking Community Hospital (Virgin Care)
# 2                      North Somerset Community Hospital
# 3                                   Bridgewater Hospital
# 4                                       Kneesworth House
# ...                                                  ...
# 19077                           Sunnybank Medical Centre
# 19078  Somerset Surgical Services At Mendip Vale Medi...
# 19079  Somerset Surgical Services At Axbridge Medical...
# 19080                               Lawton House Surgery
# 19081  Somerset Surgical Services At Wedmore Medical ...
#
#                                 Address1        Address2  ...  \
# 0                                   None     Rodney Road  ...
# 1                                   None  Heathside Road  ...
# 2      North Somerset Community Hospital      Old Street  ...
# 3                      120 Princess Road            None  ...
# 4                         Old North Road    Bassingbourn  ...
# ...                                  ...             ...  ...
# 19077                          Town Gate            Wyke  ...
# 19078                   Pudding Pie Lane        Langford  ...
# 19079                       Houlgate Way            None  ...
# 19080                       Bromley Road            None  ...
# 19081                    St. Medard Road            None  ...
#
#                    County  Postcode   Latitude  Longitude  ParentODSCode  \
# 0                  Surrey  KT12 3LD  51.379997  -0.406042            NDA
# 1                  Surrey  GU22 7HS  51.315132  -0.556289            NDA
# 2                    Avon  BS21 6BS  51.437195  -2.847193            NLT
# 3      Greater Manchester   M15 5AT  53.459743  -2.245469            NMP
# 4                    None   SG8 5JP  52.078121  -0.030604            NMV
# ...                   ...       ...        ...        ...            ...
# 19077                None  BD12 9NG  53.737923  -1.767982           None
# 19078                None  BS40 5EL  51.341579  -2.784808           None
# 19079                None  BS26 2BJ  51.286285  -2.820388           None
# 19080                None  CW12 1QG  53.163048  -2.205781           None
# 19081                None  BS28 4AY  51.227219  -2.816258           None
#
#                                               ParentName          Phone  \
# 0                               Virgin Care Services Ltd   01932 414205
# 1                               Virgin Care Services Ltd   01483 715911
# 2      North Somerset Community Partnership Community...   01275 872212
# 3                  Bridgewater Hospital (Manchester) Ltd   0161 2270000
# 4                               Partnerships In Care Ltd  01763 255 700
# ...                                                  ...            ...
# 19077                                               None           None
# 19078                                               None           None
# 19079                                               None           None
# 19080                                               None           None
# 19081                                               None           None
#
#                                                    Email  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      reception_kneesworthhouse@partnershipsincare.c...
# ...                                                  ...
# 19077                                               None
# 19078                                               None
# 19079                                               None
# 19080                                               None
# 19081                                               None
#
#                             Website           Fax
# 0                              None  01932 253674
# 1                              None          None
# 2       http://www.nscphealth.co.uk          None
# 3       www.bridgewaterhospital.com          None
# 4      www.partnershipsincare.co.uk          None
# ...                             ...           ...
# 19077                          None          None
# 19078                          None          None
# 19079                          None          None
# 19080                          None          None
# 19081                          None          None
#
# [20311 rows x 22 columns]

# %% [markdown]
# Since we will be using the coordinates of those facilities, keep only those rows that are non-null in both  `Latitude` and `Longitude`.
#
# **Tip**: Reset the index of `all_med` with `.reset_index(drop=True)`.

# %%
all_med = all_med.dropna(subset=["Latitude", "Longitude"])

all_med = all_med.reset_index(drop=True)

all_med
# Out:
#        OrganisationID OrganisationCode OrganisationType   SubType  \
# 0               17970            NDA07         Hospital  Hospital
# 1               17981            NDA18         Hospital  Hospital
# 2               18102            NLT02         Hospital  Hospital
# 3               18138            NMP01         Hospital  Hospital
# 4               18142            NMV01         Hospital  Hospital
# ...               ...              ...              ...       ...
# 20296        10617742            NBG7L           Clinic   UNKNOWN
# 20297        10617743            NFH02           Clinic   UNKNOWN
# 20298        10617744            NFH03           Clinic   UNKNOWN
# 20299        10617746            NEMAM           Clinic   UNKNOWN
# 20300        10617747            NFH04           Clinic   UNKNOWN
#
#                    Sector OrganisationStatus  IsPimsManaged  \
# 0      Independent Sector            Visible           True
# 1      Independent Sector            Visible           True
# 2              NHS Sector            Visible           True
# 3      Independent Sector            Visible          False
# 4      Independent Sector            Visible           True
# ...                   ...                ...            ...
# 20296                None            Visible          False
# 20297                None            Visible          False
# 20298                None            Visible          False
# 20299                None            Visible          False
# 20300                None            Visible          False
#
#                                         OrganisationName  \
# 0      Walton Community Hospital - Virgin Care Servic...
# 1                Woking Community Hospital (Virgin Care)
# 2                      North Somerset Community Hospital
# 3                                   Bridgewater Hospital
# 4                                       Kneesworth House
# ...                                                  ...
# 20296                           Sunnybank Medical Centre
# 20297  Somerset Surgical Services At Mendip Vale Medi...
# 20298  Somerset Surgical Services At Axbridge Medical...
# 20299                               Lawton House Surgery
# 20300  Somerset Surgical Services At Wedmore Medical ...
#
#                                 Address1        Address2  ...  \
# 0                                   None     Rodney Road  ...
# 1                                   None  Heathside Road  ...
# 2      North Somerset Community Hospital      Old Street  ...
# 3                      120 Princess Road            None  ...
# 4                         Old North Road    Bassingbourn  ...
# ...                                  ...             ...  ...
# 20296                          Town Gate            Wyke  ...
# 20297                   Pudding Pie Lane        Langford  ...
# 20298                       Houlgate Way            None  ...
# 20299                       Bromley Road            None  ...
# 20300                    St. Medard Road            None  ...
#
#                    County  Postcode   Latitude  Longitude  ParentODSCode  \
# 0                  Surrey  KT12 3LD  51.379997  -0.406042            NDA
# 1                  Surrey  GU22 7HS  51.315132  -0.556289            NDA
# 2                    Avon  BS21 6BS  51.437195  -2.847193            NLT
# 3      Greater Manchester   M15 5AT  53.459743  -2.245469            NMP
# 4                    None   SG8 5JP  52.078121  -0.030604            NMV
# ...                   ...       ...        ...        ...            ...
# 20296                None  BD12 9NG  53.737923  -1.767982           None
# 20297                None  BS40 5EL  51.341579  -2.784808           None
# 20298                None  BS26 2BJ  51.286285  -2.820388           None
# 20299                None  CW12 1QG  53.163048  -2.205781           None
# 20300                None  BS28 4AY  51.227219  -2.816258           None
#
#                                               ParentName          Phone  \
# 0                               Virgin Care Services Ltd   01932 414205
# 1                               Virgin Care Services Ltd   01483 715911
# 2      North Somerset Community Partnership Community...   01275 872212
# 3                  Bridgewater Hospital (Manchester) Ltd   0161 2270000
# 4                               Partnerships In Care Ltd  01763 255 700
# ...                                                  ...            ...
# 20296                                               None           None
# 20297                                               None           None
# 20298                                               None           None
# 20299                                               None           None
# 20300                                               None           None
#
#                                                    Email  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      reception_kneesworthhouse@partnershipsincare.c...
# ...                                                  ...
# 20296                                               None
# 20297                                               None
# 20298                                               None
# 20299                                               None
# 20300                                               None
#
#                             Website           Fax
# 0                              None  01932 253674
# 1                              None          None
# 2       http://www.nscphealth.co.uk          None
# 3       www.bridgewaterhospital.com          None
# 4      www.partnershipsincare.co.uk          None
# ...                             ...           ...
# 20296                          None          None
# 20297                          None          None
# 20298                          None          None
# 20299                          None          None
# 20300                          None          None
#
# [20301 rows x 22 columns]

# %% [markdown]
# ## Make Grid Coordinates for Medical Facilities

# %% [markdown]
# Provided for you in the next cell (which you can expand by clicking on the "...", and contract again after executing by clicking on the blue left border of the cell) is the lat/long to grid coordinates converter you have used earlier in the workshop. Use this converter to create grid coordinate values stored in `northing` and `easting` columns of the `all_med` DataFrame you created in the last step.

# %%
# https://www.ordnancesurvey.co.uk/docs/support/guide-coordinate-systems-great-britain.pdf

def latlong2osgbgrid_cupy(lat, long, input_degrees=True):
    '''
    Converts latitude and longitude (ellipsoidal) coordinates into northing and easting (grid) coordinates, using a Transverse Mercator projection.

    Inputs:
    lat: latitude coordinate (N)
    long: longitude coordinate (E)
    input_degrees: if True (default), interprets the coordinates as degrees; otherwise, interprets coordinates as radians

    Output:
    (northing, easting)
    '''

    if input_degrees:
        lat = lat * cp.pi/180
        long = long * cp.pi/180

    a = 6377563.396
    b = 6356256.909
    e2 = (a**2 - b**2) / a**2

    N0 = -100000 # northing of true origin
    E0 = 400000 # easting of true origin
    F0 = .9996012717 # scale factor on central meridian
    phi0 = 49 * cp.pi / 180 # latitude of true origin
    lambda0 = -2 * cp.pi / 180 # longitude of true origin and central meridian

    sinlat = cp.sin(lat)
    coslat = cp.cos(lat)
    tanlat = cp.tan(lat)

    latdiff = lat-phi0
    longdiff = long-lambda0

    n = (a-b) / (a+b)
    nu = a * F0 * (1 - e2 * sinlat ** 2) ** -.5
    rho = a * F0 * (1 - e2) * (1 - e2 * sinlat ** 2) ** -1.5
    eta2 = nu / rho - 1
    M = b * F0 * ((1 + n + 5/4 * (n**2 + n**3)) * latdiff -
                  (3*(n+n**2) + 21/8 * n**3) * cp.sin(latdiff) * cp.cos(lat+phi0) +
                  15/8 * (n**2 + n**3) * cp.sin(2*(latdiff)) * cp.cos(2*(lat+phi0)) -
                  35/24 * n**3 * cp.sin(3*(latdiff)) * cp.cos(3*(lat+phi0)))
    I = M + N0
    II = nu/2 * sinlat * coslat
    III = nu/24 * sinlat * coslat ** 3 * (5 - tanlat ** 2 + 9 * eta2)
    IIIA = nu/720 * sinlat * coslat ** 5 * (61-58 * tanlat**2 + tanlat**4)
    IV = nu * coslat
    V = nu / 6 * coslat**3 * (nu/rho - cp.tan(lat)**2)
    VI = nu / 120 * coslat ** 5 * (5 - 18 * tanlat**2 + tanlat**4 + 14 * eta2 - 58 * tanlat**2 * eta2)

    northing = I + II * longdiff**2 + III * longdiff**4 + IIIA * longdiff**6
    easting = E0 + IV * longdiff + V * longdiff**3 + VI * longdiff**5

    return(northing, easting)

# %%
cupy_lat = cp.asarray(all_med["Latitude"])
cupy_long = cp.asarray(all_med["Longitude"])

all_med['northing'], all_med['easting'] = latlong2osgbgrid_cupy(cupy_lat, cupy_long)
all_med
# Out:
#        OrganisationID OrganisationCode OrganisationType   SubType  \
# 0               17970            NDA07         Hospital  Hospital
# 1               17981            NDA18         Hospital  Hospital
# 2               18102            NLT02         Hospital  Hospital
# 3               18138            NMP01         Hospital  Hospital
# 4               18142            NMV01         Hospital  Hospital
# ...               ...              ...              ...       ...
# 20296        10617742            NBG7L           Clinic   UNKNOWN
# 20297        10617743            NFH02           Clinic   UNKNOWN
# 20298        10617744            NFH03           Clinic   UNKNOWN
# 20299        10617746            NEMAM           Clinic   UNKNOWN
# 20300        10617747            NFH04           Clinic   UNKNOWN
#
#                    Sector OrganisationStatus  IsPimsManaged  \
# 0      Independent Sector            Visible           True
# 1      Independent Sector            Visible           True
# 2              NHS Sector            Visible           True
# 3      Independent Sector            Visible          False
# 4      Independent Sector            Visible           True
# ...                   ...                ...            ...
# 20296                None            Visible          False
# 20297                None            Visible          False
# 20298                None            Visible          False
# 20299                None            Visible          False
# 20300                None            Visible          False
#
#                                         OrganisationName  \
# 0      Walton Community Hospital - Virgin Care Servic...
# 1                Woking Community Hospital (Virgin Care)
# 2                      North Somerset Community Hospital
# 3                                   Bridgewater Hospital
# 4                                       Kneesworth House
# ...                                                  ...
# 20296                           Sunnybank Medical Centre
# 20297  Somerset Surgical Services At Mendip Vale Medi...
# 20298  Somerset Surgical Services At Axbridge Medical...
# 20299                               Lawton House Surgery
# 20300  Somerset Surgical Services At Wedmore Medical ...
#
#                                 Address1        Address2  ...   Latitude  \
# 0                                   None     Rodney Road  ...  51.379997
# 1                                   None  Heathside Road  ...  51.315132
# 2      North Somerset Community Hospital      Old Street  ...  51.437195
# 3                      120 Princess Road            None  ...  53.459743
# 4                         Old North Road    Bassingbourn  ...  52.078121
# ...                                  ...             ...  ...        ...
# 20296                          Town Gate            Wyke  ...  53.737923
# 20297                   Pudding Pie Lane        Langford  ...  51.341579
# 20298                       Houlgate Way            None  ...  51.286285
# 20299                       Bromley Road            None  ...  53.163048
# 20300                    St. Medard Road            None  ...  51.227219
#
#        Longitude  ParentODSCode  \
# 0      -0.406042            NDA
# 1      -0.556289            NDA
# 2      -2.847193            NLT
# 3      -2.245469            NMP
# 4      -0.030604            NMV
# ...          ...            ...
# 20296  -1.767982           None
# 20297  -2.784808           None
# 20298  -2.820388           None
# 20299  -2.205781           None
# 20300  -2.816258           None
#
#                                               ParentName          Phone  \
# 0                               Virgin Care Services Ltd   01932 414205
# 1                               Virgin Care Services Ltd   01483 715911
# 2      North Somerset Community Partnership Community...   01275 872212
# 3                  Bridgewater Hospital (Manchester) Ltd   0161 2270000
# 4                               Partnerships In Care Ltd  01763 255 700
# ...                                                  ...            ...
# 20296                                               None           None
# 20297                                               None           None
# 20298                                               None           None
# 20299                                               None           None
# 20300                                               None           None
#
#                                                    Email  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      reception_kneesworthhouse@partnershipsincare.c...
# ...                                                  ...
# 20296                                               None
# 20297                                               None
# 20298                                               None
# 20299                                               None
# 20300                                               None
#
#                             Website           Fax       northing  \
# 0                              None  01932 253674  165810.473974
# 1                              None          None  158381.343420
# 2       http://www.nscphealth.co.uk          None  171305.775859
# 3       www.bridgewaterhospital.com          None  395944.561405
# 4      www.partnershipsincare.co.uk          None  244071.710013
# ...                             ...           ...            ...
# 20296                          None          None  426887.040596
# 20297                          None          None  160625.127012
# 20298                          None          None  154503.665383
# 20299                          None          None  362932.494686
# 20300                          None          None  147932.429756
#
#              easting
# 0      510917.517174
# 1      500604.836652
# 2      341119.365090
# 3      383703.600293
# 4      534945.182860
# ...              ...
# 20296  415302.519662
# 20297  345341.262026
# 20298  342794.591249
# 20299  386243.408863
# 20300  343009.593212
#
# [20301 rows x 24 columns]

# %% [markdown]
# ## Find Closest Hospital or Clinic for Infected

# %% [markdown]
# Fit `cuml.NearestNeighbors` with `all_med`'s `northing` and `easting` values, using the named argument `n_neighbors` set to `1`, and save the model as `knn`.

# %% [markdown]
# ### BEGIN: MWE

# %%
all_med[["northing", "easting"]]
# Out:
#             northing        easting
# 0      165810.473974  510917.517174
# 1      158381.343420  500604.836652
# 2      171305.775859  341119.365090
# 3      395944.561405  383703.600293
# 4      244071.710013  534945.182860
# ...              ...            ...
# 20296  426887.040596  415302.519662
# 20297  160625.127012  345341.262026
# 20298  154503.665383  342794.591249
# 20299  362932.494686  386243.408863
# 20300  147932.429756  343009.593212
#
# [20301 rows x 2 columns]

# %% [markdown]
# ### END: MWE

# %%
knn = cuml.NearestNeighbors(n_neighbors=1)
knn.fit(all_med[["northing", "easting"]])
# Out:
# NearestNeighbors()

# %% [markdown]
# Save every infected member in `df` into a new dataframe called `infected_df`.
#
# **Tip**: Reset the index of `infected_df` with `.reset_index(drop=True)`.

# %% [markdown]
# ### BEGIN: MWE

# %%
df["infected"].value_counts()
# Out:
# infected
# 0.0    58409014
# 1.0       70880
# Name: count, dtype: int64

# %% [markdown]
# ### END: MWE

# %%
infected_filter = df['infected']==1.0
infected_df = df[infected_filter]
infected_df.reset_index(drop=True)
# Out:
#              lat      long  infected
# 0      53.715826 -2.430079       1.0
# 1      53.664881 -2.425673       1.0
# 2      53.696765 -2.488940       1.0
# 3      53.696966 -2.488897       1.0
# 4      53.727804 -2.392959       1.0
# ...          ...       ...       ...
# 70875  51.662717 -2.926850       1.0
# 70876  51.599350 -2.959175       1.0
# 70877  51.543825 -2.822984       1.0
# 70878  51.562536 -2.879492       1.0
# 70879  51.628748 -2.837151       1.0
#
# [70880 rows x 3 columns]

# %% [markdown]
# Create `northing` and `easting` values for `infected_df`.

# %%
cupy_infected_lat = cp.asarray(infected_df["lat"])
cupy_infected_long = cp.asarray(infected_df["long"])

infected_df['northing'], infected_df['easting'] = latlong2osgbgrid_cupy(cupy_infected_lat, cupy_infected_long)
infected_df
# Out:
#                 lat      long  infected       northing        easting
# 1346586   53.715826 -2.430079       1.0  424489.783814  371619.678741
# 1350932   53.664881 -2.425673       1.0  418820.687944  371876.492369
# 1352085   53.696765 -2.488940       1.0  422394.398940  367721.000265
# 1352799   53.696966 -2.488897       1.0  422416.821887  367723.973098
# 1357529   53.727804 -2.392959       1.0  425808.109929  374076.557677
# ...             ...       ...       ...            ...            ...
# 58459189  51.662717 -2.926850       1.0  196451.131712  335900.971171
# 58459551  51.599350 -2.959175       1.0  189433.449408  333573.002864
# 58461935  51.543825 -2.822984       1.0  183143.984735  342935.130365
# 58464082  51.562536 -2.879492       1.0  185270.296666  339042.062616
# 58464209  51.628748 -2.837151       1.0  192598.790941  342060.980289
#
# [70880 rows x 5 columns]

# %% [markdown]
# Use `knn.kneighbors` with `n_neighbors=1` on `infected_df`'s `northing` and `easting` values. Save the return values in `distances` and `indices`.

# %%
distances, indices = knn.kneighbors(infected_df[["northing", "easting"]], 1)
infected_df['distance']=distances
infected_df['closest_clinic_hospital']=indices
infected_df
# Out:
#                 lat      long  infected       northing        easting  \
# 1346586   53.715826 -2.430079       1.0  424489.783814  371619.678741
# 1350932   53.664881 -2.425673       1.0  418820.687944  371876.492369
# 1352085   53.696765 -2.488940       1.0  422394.398940  367721.000265
# 1352799   53.696966 -2.488897       1.0  422416.821887  367723.973098
# 1357529   53.727804 -2.392959       1.0  425808.109929  374076.557677
# ...             ...       ...       ...            ...            ...
# 58459189  51.662717 -2.926850       1.0  196451.131712  335900.971171
# 58459551  51.599350 -2.959175       1.0  189433.449408  333573.002864
# 58461935  51.543825 -2.822984       1.0  183143.984735  342935.130365
# 58464082  51.562536 -2.879492       1.0  185270.296666  339042.062616
# 58464209  51.628748 -2.837151       1.0  192598.790941  342060.980289
#
#               distance  closest_clinic_hospital
# 1346586    2562.830078                    18316
# 1350932    2988.618164                    12816
# 1352085    1162.685059                     7785
# 1352799    1162.283203                     7785
# 1357529    1455.115601                     4962
# ...                ...                      ...
# 58459189   8617.324219                    10015
# 58459551   1306.979248                    10015
# 58461935   7633.295410                     3814
# 58464082   7071.362305                    10015
# 58464209  10222.643555                    10015
#
# [70880 rows x 7 columns]

# %% [markdown]
# ### View Closest Clinic/Hospital ###

# %% [markdown]
# `indices`, returned from your use of `knn.kneighbors` immediately above, should map person indices to their closest clinic/hospital indices:

# %% [markdown]
# Here you can print an infected individual's coordinates from `infected_df`:

# %%
infected_df.iloc[0] # get the coords of an infected individual (in this case, individual 0)
# Out:
# lat                            53.715826
# long                           -2.430079
# infected                        1.000000
# northing                   424489.783814
# easting                    371619.678741
# distance                     2562.830078
# closest_clinic_hospital     18316.000000
# Name: 1346586, dtype: float64

# %% [markdown]
# You should be able to used the mapped index for the nearest facility to see that indeed the nearest facility is at a nearby coordinate:

# %%
all_med.iloc[18316] # printing the entry for facility 1234 (replace with the index identified as closest to the individual)
# Out:
# OrganisationID                                             9445963
# OrganisationCode                                             NPR0F
# OrganisationType                                            Clinic
# SubType                                                    UNKNOWN
# Sector                                                        None
# OrganisationStatus                                         Visible
# IsPimsManaged                                                False
# OrganisationName      Community Dermatology Service - About Health
# Address1                                     The Innovation Centre
# Address2                                          1 Evolution Park
# Address3                                           Haslingden Road
# City                                                     Blackburn
# County                                                  Lancashire
# Postcode                                                   BB1 2FD
# Latitude                                                 53.733227
# Longitude                                                -2.455536
# ParentODSCode                                                 None
# ParentName                                                    None
# Phone                                                         None
# Email                                                         None
# Website                                                       None
# Fax                                                           None
# northing                                             426435.969251
# easting                                              369952.220236
# Name: 18316, dtype: object

# %% [markdown]
# ## New Patients ##

# %% [markdown]
# Use the `knn` model to find the closest clinic/hospital for the below new patients.

# %%
# DO NOT CHANGE THIS CELL
patients=[
    {
        "name":"John Smith",
        "northing":462643.2282915547,
        "easting":363859.7580565622
    },
        {
        "name":"Greg Brown",
        "northing":409324.1030472915,
        "easting":464084.5085059871
    }
]

patients_df=pd.DataFrame(patients)

patients_df['distance'], patients_df['closest_clinic_hospital'] = knn.kneighbors(patients_df[['northing', 'easting']])

patients_df['OrganisationID'] = patients_df.apply(lambda x: all_med.loc[x['closest_clinic_hospital'], "OrganisationID"], axis=1)

patients_df
# Out:
#          name       northing        easting     distance  \
# 0  John Smith  462643.228292  363859.758057  7286.685059
# 1  Greg Brown  409324.103047  464084.508506  1561.915405
#
#    closest_clinic_hospital  OrganisationID
# 0                     4637           64351
# 1                     3886           62389

# %%
#patients_df.to_json('my_assessment/question_2.json', orient='records')
patients_df.to_json( Path(base_path, "my_assessment", "question_2.json"), orient='records')
# Out:
# /usr/local/lib/python3.12/dist-packages/cudf/io/json.py:426: UserWarning: Using CPU via Pandas to write JSON dataset
#   warnings.warn("Using CPU via Pandas to write JSON dataset")

# %% [markdown]
# ## Check Submission ##

# %%
# !cat my_assessment/question_2.json

# %% [markdown]
# **Tip**: Your submission file should contain one line of text, similar to:
#
# ```
# [{'name':'John Smith','northing':XXX.XX,'easting':XXX.XX,'closest_clinic_hospital':XX,'OrganisationID':XX},{'name':'Greg Brown','northing':XXX.XX,'easting':XXX.XX,'closest_clinic_hospital':XX,'OrganisationID':XX}]
# ```

# %% [markdown]
# <div align="center"><h2>Please Restart the Kernel</h2></div>

# %% [markdown]
# ...before moving to the next notebook.

# %%
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)

# %% [markdown]
# <a href="https://www.nvidia.com/dli"><img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/></a>
